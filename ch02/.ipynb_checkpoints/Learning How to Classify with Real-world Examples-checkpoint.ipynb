# %%
from matplotlib import pyplot as plt
import numpy as np
import scipy as sp
from sklearn.datasets import load_iris
from threshold import learn_model, apply_model, accuracy

# %matplotlib inline

# %%
# We load the data with load_iris from sklearn
data = load_iris()
features = data['data']
feature_names = data['feature_names']
target = data['target']

# %%
for t,marker,c in zip(xrange(3),">ox","rgb"):
    # We plot each class on its own to get different colored markers
    plt.scatter(features[target == t,0],
                features[target == t,1],
                marker=marker, c=c)

# %%
import itertools

pairs = []

for i,p in enumerate(list(itertools.product(range(4), range(4)))):
    if p not in pairs and (p[1], p[0]) not in pairs and p[0] != p[1]:
        pairs.append(p)
        
print pairs
# Out:
# [(0, 1), (0, 2), (0, 3), (1, 2), (1, 3), (2, 3)]

# %%
plt.figure(figsize=(10,6))
for i,(p0,p1) in enumerate(pairs):
    plt.subplot(2,3,i+1)
    for t,marker,c in zip(xrange(3),">ox","rgb"):
        # We plot each class on its own to get different colored markers
#         target_name = data['target_names'][t]
        plt.scatter(features[target == t,p0],
                    features[target == t,p1],
                    marker=marker, c=c)
        plt.xlabel(feature_names[p0])
        plt.ylabel(feature_names[p1])
        plt.xticks([])
        plt.yticks([])
    
    plt.tight_layout()

# %% [markdown]
# ## Building our first classification model

# %%
labels = data['target_names'][data['target']]

# %%
plength = features[:, 2]
# use numpy operations to get setosa features
is_setosa = (labels == 'setosa')
# This is the important step:
max_setosa = plength[is_setosa].max()
min_non_setosa = plength[~is_setosa].min()
print('Maximum of setosa: {0}.'.format(max_setosa))
print('Minimum of others: {0}.'.format(min_non_setosa))
# Out:
# Maximum of setosa: 1.9.
# Minimum of others: 3.0.

# %%
# if features[:,2] < 2: print 'Iris Setosa'
# else: print 'Iris Virginica or Iris Versicolour'

labels[features[:,2] < 2]
# Out:
# array(['setosa', 'setosa', 'setosa', 'setosa', 'setosa', 'setosa',
#        'setosa', 'setosa', 'setosa', 'setosa', 'setosa', 'setosa',
#        'setosa', 'setosa', 'setosa', 'setosa', 'setosa', 'setosa',
#        'setosa', 'setosa', 'setosa', 'setosa', 'setosa', 'setosa',
#        'setosa', 'setosa', 'setosa', 'setosa', 'setosa', 'setosa',
#        'setosa', 'setosa', 'setosa', 'setosa', 'setosa', 'setosa',
#        'setosa', 'setosa', 'setosa', 'setosa', 'setosa', 'setosa',
#        'setosa', 'setosa', 'setosa', 'setosa', 'setosa', 'setosa',
#        'setosa', 'setosa'],
#       dtype='|S10')

# %%
np.mean(labels[features[:,2] < 2] == 'setosa')
# Out:
# 1.0

# %%
# th = threshold
# fi = features
# model = (best_t, best_fi)
naive_model = (2.0, 2)

# %%
def apply_model(features, model):
    t, fi = model
    return features[:,fi] < t

# %% [markdown]
# ## resetting variables, be careful of rerunning cells above

# %%
# the non-Setosa features and labels:
features = features[~is_setosa]
labels = labels[~is_setosa]
virginica = (labels == 'virginica')

# %%
# run a loop over all possible features and thresholds to see which one results in better accuracy
# Accuracy is simply the fraction of examples that the model classifies correctly

best_acc = -1.0
for fi in xrange(features.shape[1]):
    # We are going to generate all possible threshold for this feature
    thresh = features[:,fi].copy()
    thresh.sort()
    # Now test all thresholds:
    for t in thresh:
        pred = (features[:,fi] > t)
        acc = (pred == virginica).mean()
        if acc > best_acc:
            best_acc = acc
            best_fi = fi
            best_t = t

# %%
print best_acc, feature_names[best_fi], best_t
# Out:
# 0.94 petal width (cm) 1.6

# %%
virginica
# Out:
# array([False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,  True], dtype=bool)

# %%
t_x = np.ones(50) * 1.65
t_y = np.linspace(2,8)
plt.scatter(features[virginica, best_fi], features[virginica, 2], marker='o', c='b')
plt.scatter(features[~virginica, best_fi], features[~virginica, 2], marker='x', c='r')

plt.plot(t_x, t_y, 'k:')
plt.xlim((.9,2.6))
plt.ylim((2.9,7.5))

plt.axvspan(1.75, 2.6, facecolor='c', alpha=0.5, ls='--')

# %%
error = 0.0
for ei in range(len(features)):
    # select all but the one at position 'ei':
    training = np.ones(len(features), bool)
    training[ei] = False
    testing = ~training
    model = learn_model(features[training], virginica[training])
    predictions = accuracy(features[testing], virginica[testing], model)
    error += np.sum(predictions != virginica[testing])

print error/len(features)
# Out:
# 0.51

# %% [markdown]
# ## nearest neighbor classification with Seeds
#
# Seven features are present, as follows:
#
#     • Area (A)
#     • Perimeter (P)
#     • Compactness ( )
#     • Length of kernel
#     • Width of kernel
#     • Asymmetry coefficient
#     • Length of kernel groove

# %%
seeds = []
labels = []
with open('data/seeds.tsv', 'r') as ifile:
    for line in ifile:
        tokens = line.strip().split('\t')
        seeds.append([float(tk) for tk in tokens[:-1]])
        labels.append(tokens[-1])
seeds = np.array(seeds)
labels = np.array(labels)

seeds
# Out:
# array([[ 15.26  ,  14.84  ,   0.871 , ...,   3.312 ,   2.221 ,   5.22  ],
#        [ 14.88  ,  14.57  ,   0.8811, ...,   3.333 ,   1.018 ,   4.956 ],
#        [ 14.29  ,  14.09  ,   0.905 , ...,   3.337 ,   2.699 ,   4.825 ],
#        ...,
#        [ 13.2   ,  13.66  ,   0.8883, ...,   3.232 ,   8.315 ,   5.056 ],
#        [ 11.84  ,  13.21  ,   0.8521, ...,   2.836 ,   3.598 ,   5.044 ],
#        [ 12.3   ,  13.34  ,   0.8684, ...,   2.974 ,   5.637 ,   5.063 ]])

# %%
def distance(p0, p1):
    # squared Euclidean distance
    return np.sum( (p0-p1)**2 )

# %%
def nn_classify(training_set, training_labels, new_example):
    dists = np.array([distance(t, new_example) for t in training_set])
    nearest = dists.argmin()
    return training_labels[nearest]

# %%
test_ex = seeds[0]
print labels[0]

nn_classify(seeds, labels, test_ex)
# Out:
# Kama
# 'Kama'

# %%
kfold_acc = []

for fold in range(10):
    training = np.ones(len(seeds), bool)
    training[fold::10] = 0
    test = ~training
    correct_cnt = 0.
    for example in range(len(seeds[test])):
        correct_cnt += np.sum(nn_classify(seeds[training], labels[training], seeds[test][example]) == labels[test][example])
    kfold_acc.append(correct_cnt/len(seeds[test]))
    

np.mean(kfold_acc)
# Out:
# 0.89523809523809528

# %%
markers = {a:b for a,b in zip(np.unique(labels), ['D', 'o', '^'])}
colors = {a:b for a,b in zip(np.unique(labels), ['r', 'g', 'b'])}

for seed in range(len(seeds)):
    plt.plot(seeds[seed][0], seeds[seed][2], 
             marker=markers[labels[seed]], 
             c=colors[labels[seed]]
            )

plt.xlabel('area')
plt.ylabel('compactness')

plt.ylim((.75, 1.))
# Out:
# (0.75, 1.0)

# %%
markers = {a:b for a,b in zip(np.unique(labels), ['D', 'o', '^'])}
colors = {a:b for a,b in zip(np.unique(labels), ['w', 'k', 'y'])}

for seed in markers:
    current_seed = labels == seed
    plt.plot(seeds[current_seed][:,0], 
             seeds[current_seed][:,2], 
             markers[seed] + colors[seed],
             label=seed
            )
    
plt.xlabel('area')
plt.ylabel('compactness')

plt.ylim((.75, 1.))

plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

# %%
yComp = np.linspace(.75, 1.)
xArea = np.linspace(10, 22)

xyGrid = []
xyLab = []

for x in np.nditer(xArea):
    for y in np.nditer(yComp):
        xyGrid.append([x, y])
        label = nn_classify(seeds[:,[0,2]], labels, (x,y))
        xyLab.append(label)

xyGrid = np.array(xyGrid)
xyLab = np.array(xyLab)
print len(xyGrid)
print len(xyLab)
print xyLab[:10]
# Out:
# 2500
# 2500
# ['Canadian' 'Canadian' 'Canadian' 'Canadian' 'Canadian' 'Canadian'
#  'Canadian' 'Canadian' 'Canadian' 'Canadian']

# %%
# plt.plot(xyGrid[:,0], xyGrid[:,1], marker='.')

for dot in range(len(xyGrid)):
    plt.plot(xyGrid[dot,0], xyGrid[dot,1], marker='.', c=colors[xyLab[dot]], ms=3)
        
plt.ylim((.75, 1.))
# Out:
# (0.75, 1.0)

# %%
markers = {a:b for a,b in zip(np.unique(labels), ['D', 'o', '^'])}
colors = {a:b for a,b in zip(np.unique(labels), ['w', 'k', 'y'])}
colors2 = {a:b for a,b in zip(np.unique(labels), ['r', 'g', 'b'])}

plt.figure(figsize=(10,6))

# for x in np.nditer(xArea):
#     for y in np.nditer(yComp):
#         label = nn_classify(seeds[:,[0,2]], labels, (x,y))
#         plt.plot(x, y, marker='.', c=colors[label])

for dot in range(len(xyGrid)):
    plt.plot(xyGrid[dot,0], xyGrid[dot,1], marker='s', 
             c=colors[xyLab[dot]], ms=12, alpha=.3, markeredgecolor='red',
             markeredgewidth=0.0)

for seed in markers:
    current_seed = labels == seed
    plt.plot(seeds[current_seed][:,0], 
             seeds[current_seed][:,2], 
#              markers[seed] + 'w',
             markers[seed] + colors[seed],
#              markers[seed] + colors2[seed],
             label=seed
            )

        
plt.xlabel('area')
plt.ylabel('compactness')

plt.ylim((.75, 1.))

plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

# %% [markdown]
# ## standardize features (normalize to z-scores)

# %%
# subtract the mean for each feature:
# 
features = seeds[:,[0,2]].copy()
features -= features.mean(axis=0)
# divide each feature by its standard deviation
features /= features.std(axis=0)

# %%
markers = {a:b for a,b in zip(np.unique(labels), ['D', 'o', '^'])}
colors = {a:b for a,b in zip(np.unique(labels), ['w', 'k', 'y'])}

for seed in markers:
    current_seed = labels == seed
    plt.plot(features[current_seed][:,0], 
             features[current_seed][:,1], 
             markers[seed] + colors[seed],
             label=seed
            )
    
plt.xlabel('area')
plt.ylabel('compactness')

# plt.ylim((.75, 1.))

plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)

# %%
yComp2 = np.linspace(-3, 2)
xArea2 = np.linspace(-1.5, 2.5)

xyGrid2 = []
xyLab2 = []

for x in np.nditer(xArea2):
    for y in np.nditer(yComp2):
        xyGrid2.append([x, y])
        label = nn_classify(features, labels, (x,y))
        xyLab2.append(label)

xyGrid2 = np.array(xyGrid2)
xyLab2 = np.array(xyLab2)
print len(xyGrid2)
print len(xyLab2)
print xyLab2[:10]
# Out:
# 2500
# 2500
# ['Canadian' 'Canadian' 'Canadian' 'Canadian' 'Canadian' 'Canadian'
#  'Canadian' 'Canadian' 'Canadian' 'Canadian']

# %%
for dot in range(len(xyGrid2)):
    plt.plot(xyGrid2[dot,0], xyGrid2[dot,1], marker='.', c=colors[xyLab2[dot]], ms=3)
        
# plt.ylim((.75, 1.))

# %%
markers = {a:b for a,b in zip(np.unique(labels), ['D', 'o', '^'])}
colors = {a:b for a,b in zip(np.unique(labels), ['w', 'k', 'y'])}

plt.figure(figsize=(10,6))

for dot in range(len(xyGrid2)):
    plt.plot(xyGrid2[dot,0], xyGrid2[dot,1], marker='.', c=colors[xyLab2[dot]], ms=3)
    
for seed in markers:
    current_seed = labels == seed
    plt.plot(features[current_seed][:,0], 
             features[current_seed][:,1], 
             markers[seed] + colors[seed],
             label=seed
            )
    
plt.xlabel('area')
plt.ylabel('compactness')

plt.ylim((-3, 2))

plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
